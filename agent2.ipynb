# %%
from langgraph.graph import StateGraph
from typing import TypedDict, Dict, List

# %%
class AgentState(TypedDict):
    values: List[int]
    name: str
    result:str

def process_values(state:AgentState)->AgentState:
    """This function processes the values for the state"""
    state["result"] = f"Hi there, {state["name"]}, your total sum is {sum(state["values"])}"

    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("processor", process_values)
graph.set_entry_point("processor")
graph.set_finish_point("processor")

# %%
app = graph.compile()
answer = app.invoke({"name":"bob", "values":[1,2,3,4]})

# %%
print(answer)
# Out:
# {'values': [1, 2, 3, 4], 'name': 'bob', 'result': 'Hi there, bob, your total sum is 10'}
